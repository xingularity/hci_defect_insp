# %%
# !nvidia-smi

# %%
from __future__ import print_function
import keras
from keras import metrics
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

import tensorflow as tf
# 自動增長 GPU 記憶體用量
gpu_options = tf.GPUOptions(allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# 設定 Keras 使用的 Session
tf.keras.backend.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
import os
img_base_path = '/home/z99792458/nbs/Dataset/img_defects/hci_defect_datasets/'
class1_path = os.path.join(img_base_path, 'Class10')
class1_train_path = os.path.join(class1_path, 'Train')
class1_test_path = os.path.join(class1_path, 'Test')
labeled_img = [x[:4] for x in os.listdir(os.path.join(class1_train_path, 'Label'))] + [x[:4] for x in os.listdir(os.path.join(class1_test_path, 'Label'))]
labeled_img = list(set(labeled_img))
all_img = [x for x in os.listdir(class1_train_path) if x.find('_256') >-1] + [x for x in os.listdir(class1_test_path) if x.find('_256') >-1]
normal_img_name = [x for x in all_img if x[:4] not in labeled_img]
defect_img_name = [x for x in all_img if x[:4] in labeled_img]
train_img_names, test_img_names = train_test_split(normal_img_name, test_size=0.25)

train_imgs = list()
test_imgs = list()
for img_name in os.listdir(class1_train_path):
    if (img_name in train_img_names) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_train_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            train_imgs.append(img)
    if (img_name in test_img_names) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_train_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            test_imgs.append(img)

for img_name in os.listdir(class1_test_path):
    if (img_name in train_img_names) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_test_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            train_imgs.append(img)
    if (img_name in test_img_names) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_test_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            test_imgs.append(img)

train_imgs = (np.stack(train_imgs)).astype(float)/255
test_imgs = (np.stack(test_imgs)).astype(float)/255

img_shape = train_imgs.shape[1:]
num_units = img_shape[0]*img_shape[1]*img_shape[2]

train_imgs = train_imgs.reshape(train_imgs.shape[0], num_units)
test_imgs = test_imgs.reshape(test_imgs.shape[0], num_units)

# %%
# Get defected images
defect_imgs = list()
for img_name in os.listdir(class1_train_path):
    if (img_name in defect_img_name) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_train_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            defect_imgs.append(img)
for img_name in os.listdir(class1_test_path):
    if (img_name in defect_img_name) and (img_name.find('_256') > -1) and (img_name.find('PNG') > -1):
        img = cv2.imread(os.path.join(class1_train_path, img_name), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = img.reshape(img.shape[0], img.shape[1], 1)
            defect_imgs.append(img)
defect_imgs = (np.stack(defect_imgs)).astype(float)/255
defect_imgs = defect_imgs.reshape(defect_imgs.shape[0], -1)

# %%
train_imgs.shape
# Out:
# (1500, 65536)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1.e-3
    if epoch > 20000:
        lr *= 1.e-2
    elif epoch > 10000:
        lr *= 1e-1
    elif epoch > 2000:
        lr *= 1.e-1
    elif epoch > 500:
        lr *= 1.0e-1
    print('Learning rate: ', lr)
    return lr

# %%
encoding_dim =  int(train_imgs.shape[1]/32) # encoded output

# Autoencoder Model
input_img = Input(shape=(train_imgs.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(train_imgs.shape[1], activation='sigmoid')(encoded)
autoencoder = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# Decoder Model
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer=Adam(lr=lr_schedule(0)), loss='mse', metrics=[metrics.mae])
autoencoder.summary()
# Out:
# WARNING:tensorflow:From /home/z99792458/anaconda_env/tf/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Learning rate:  0.001
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 65536)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              134219776
# _________________________________________________________________
# dense_2 (Dense)              (None, 65536)             134283264
# =================================================================
# Total params: 268,503,040
# Trainable params: 268,503,040
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
import datetime as dt
model_name_prefix = 'deep_autoencoder_class10_%s' % ( dt.datetime.now().strftime("%Y%m%d%H"))
model_name = model_name_prefix + '_{epoch:03d}.h5' 
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

# %%
callbacks = [lr_reducer, lr_scheduler]
# callbacks = []

# %%
# Run training
history = autoencoder.fit(train_imgs, train_imgs,
          batch_size=32,
          epochs=30000,
          validation_data=(test_imgs, test_imgs),
          shuffle=True,
          callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /home/z99792458/anaconda_env/tf/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1500 samples, validate on 500 samples
# Epoch 1/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0091 - mean_absolute_error: 0.0723 - val_loss: 0.0070 - val_mean_absolute_error: 0.0655
# Epoch 2/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0066 - mean_absolute_error: 0.0615 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 3/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 4/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0068 - val_mean_absolute_error: 0.0643
# Epoch 5/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0610 - val_loss: 0.0065 - val_mean_absolute_error: 0.0601
# Epoch 6/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0610 - val_loss: 0.0065 - val_mean_absolute_error: 0.0603
# Epoch 7/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0608 - val_loss: 0.0065 - val_mean_absolute_error: 0.0607
# Epoch 8/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0606 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 9/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0609 - val_loss: 0.0065 - val_mean_absolute_error: 0.0601
# Epoch 10/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 11/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 12/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0608 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 13/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 14/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 15/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0606 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 16/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0065 - val_mean_absolute_error: 0.0599
# Epoch 17/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0065 - val_mean_absolute_error: 0.0600
# Epoch 18/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 19/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 20/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 21/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 22/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 23/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 24/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0608 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 25/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 26/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 27/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0065 - val_mean_absolute_error: 0.0615
# Epoch 28/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 29/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 30/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 31/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 32/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 33/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0065 - val_mean_absolute_error: 0.0600
# Epoch 34/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 35/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 36/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 37/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0066 - val_mean_absolute_error: 0.0603
# Epoch 38/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 39/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 40/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0066 - val_mean_absolute_error: 0.0600
# Epoch 41/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 42/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 43/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 44/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 45/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 46/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 47/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 48/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 49/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 50/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0065 - val_mean_absolute_error: 0.0615
# Epoch 51/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 52/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 53/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 54/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 55/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 56/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 57/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 58/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 59/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 60/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 61/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 62/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 63/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 64/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 65/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 66/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 67/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 68/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0604 - val_loss: 0.0065 - val_mean_absolute_error: 0.0620
# Epoch 69/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - val_loss: 0.0065 - val_mean_absolute_error: 0.0619
# Epoch 70/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 71/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 72/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 73/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 74/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 75/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 76/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 77/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 78/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 79/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 80/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 81/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 82/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 83/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 84/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0614
# Epoch 85/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 86/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 87/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 88/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 89/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 90/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 91/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 92/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 93/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 94/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 95/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 96/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 97/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0065 - val_mean_absolute_error: 0.0620
# Epoch 98/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0602 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 99/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 100/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 101/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 102/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 103/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 104/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 105/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0601 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 106/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 107/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0066 - val_mean_absolute_error: 0.0601
# Epoch 108/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 109/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 110/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 111/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 112/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 113/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 114/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 115/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 116/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 117/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0065 - val_mean_absolute_error: 0.0615
# Epoch 118/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0610
# Epoch 119/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 120/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0619
# Epoch 121/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 122/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0616
# Epoch 123/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 124/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 125/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0066 - val_mean_absolute_error: 0.0625
# Epoch 126/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 127/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 128/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 129/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 130/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0066 - val_mean_absolute_error: 0.0622
# Epoch 131/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 132/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 133/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0066 - val_mean_absolute_error: 0.0622
# Epoch 134/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0065 - val_mean_absolute_error: 0.0598
# Epoch 135/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 136/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 137/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 138/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 139/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0065 - val_mean_absolute_error: 0.0616
# Epoch 140/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 141/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 142/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 143/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 144/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 145/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 146/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 147/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 148/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 149/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 150/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 151/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 152/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 153/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 154/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 155/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 156/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 157/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 158/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 159/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 160/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0065 - val_mean_absolute_error: 0.0616
# Epoch 161/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0596
# Epoch 162/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 163/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 164/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 165/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 166/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 167/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 168/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 169/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 170/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 171/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 172/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0065 - val_mean_absolute_error: 0.0616
# Epoch 173/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0610
# Epoch 174/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 175/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 176/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 177/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 178/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 179/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 180/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 181/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 182/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0066 - val_mean_absolute_error: 0.0626
# Epoch 183/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 184/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 185/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 186/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 187/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 188/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 189/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0066 - val_mean_absolute_error: 0.0629
# Epoch 190/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0600 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 191/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 192/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 193/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 194/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 195/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 196/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0610
# Epoch 197/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 198/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 199/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0604 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 200/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 201/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 202/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 203/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 204/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 205/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 206/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 207/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 208/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0597
# Epoch 209/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 210/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 211/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607
# Epoch 212/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 213/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 214/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 215/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 216/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 217/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 218/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 219/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0620
# Epoch 220/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 221/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 222/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0066 - val_mean_absolute_error: 0.0622
# Epoch 223/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 224/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 225/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 226/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 227/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 228/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 229/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 230/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 231/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 232/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 233/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 234/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0608
# Epoch 235/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0066 - val_mean_absolute_error: 0.0625
# Epoch 236/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 237/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 238/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0065 - val_mean_absolute_error: 0.0617
# Epoch 239/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 240/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 241/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 242/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0598 - val_loss: 0.0064 - val_mean_absolute_error: 0.0597
# Epoch 243/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0065 - val_mean_absolute_error: 0.0613
# Epoch 244/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0597 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 245/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 246/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0594 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 247/30000
# Learning rate:  0.001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 248/30000
# Learning rate:  0.001
# ...
# Epoch 2934/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2935/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2936/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2937/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2938/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 2939/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2940/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0591 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2941/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2942/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2943/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2944/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 2945/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2946/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2947/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2948/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2949/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2950/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2951/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2952/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2953/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2954/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2955/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2956/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2957/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2958/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2959/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2960/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0591 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2961/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2962/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2963/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2964/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2965/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2966/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2967/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2968/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 2969/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2970/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2971/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2972/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2973/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2974/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2975/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2976/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2977/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2978/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2979/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2980/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0591 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2981/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2982/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2983/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2984/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2985/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 2986/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 2987/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2988/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2989/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2990/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2991/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 2992/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2993/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 2994/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2995/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2996/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 2997/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2998/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 2999/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 3000/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 3001/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 3002/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3003/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3004/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3005/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3006/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 3007/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3008/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 3009/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3010/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3011/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 3012/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0600
# Epoch 3013/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3014/30000
# Learning rate:  0.0001
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0599
# Epoch 3015/30000
# Learning rate:  0.0001
#  832/1500 [===============>..............] - ETA: 2s - loss: 0.0062 - mean_absolute_error: 0.0591

# %%
autoencoder.save_weights("./saved_models/" + model_name_prefix + "_final_models.h5")

# %%
img = defect_imgs[10]
plt.imshow(img.reshape((256, 256)))
predicted = autoencoder.predict(img.reshape(img.shape[0], 1).T)

predicted = predicted.reshape((256, 256))

# %%
plt.imshow(predicted)

# %%
img = test_imgs[2]
plt.imshow(img.reshape((256, 256)))
predicted = autoencoder.predict(img.reshape(img.shape[0], 1).T)

predicted = predicted.reshape((256,256))

# %%
plt.imshow(predicted)
